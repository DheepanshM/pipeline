# %% [markdown]
# import library pandas

# %%
import pandas as pd
import random as rd

# %% [markdown]
# read the csv files

# %%
df_transaction=pd.read_csv("transaction_data.csv")
df_us_customer=pd.read_csv("us_customer_data 1.csv")

# %% [markdown]
# Processing customer data from a CSV file for a retail company to ensure clean, unique records.
# drop the duplicate values

# %%
df_transaction=df_transaction.drop_duplicates()
df_us_customer=df_us_customer.drop_duplicates()

# %% [markdown]
# replace null values in email with the name of the customer with some randomn threshold value

# %%
df_us_customer['email']=df_us_customer['email'].fillna(df_us_customer['name'].str.replace(' ','').str.lower()+'@example.com')

# %% [markdown]
# check whether the null values are updated

# %%
df_us_customer['email'].iloc[25:30]
# Out:
# 25         chawkins@example.net
# 26    browningdavid@example.org
# 27      brandonhall@example.com
# 28       michelle12@example.net
# 29          qwillis@example.com
# Name: email, dtype: object

# %% [markdown]
# Replace amount null values with mean value

# %%
df_transaction['amount']=df_transaction['amount'].fillna(df_transaction['amount'].mean())

# %% [markdown]
# check if there are any null values

# %%
df_transaction['amount'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Standardizing contact details in an Excel file for a marketing campaign using  customer data--generate country code using address

# %%
df_us_customer['country_code']=df_us_customer['address'].str[-8:-6]

# %% [markdown]
# check for unique country codes

# %%
df_us_customer['country_code'].unique()
# Out:
# array(['AE', 'MT', 'UT', 'CA', 'OR', 'MA', 'CT', 'NC', 'WA', 'IL', 'WI',
#        'AA', 'FM', 'CO', 'AP', 'RI', 'PW', 'FL', 'IA', 'VA', 'KS', 'SD',
#        'MP', 'AL', 'MH', 'TX', 'MS', 'MD', 'NV', 'HI', 'GU', 'GA', 'ND',
#        'TN', 'ID', 'IN', 'DE', 'KY', 'NJ', 'AZ', 'MO', 'AS', 'OH', 'OK',
#        'NE', 'NY', 'DC', 'ME', 'PA', 'WY', 'VI', 'SC', 'AR', 'NH', 'PR',
#        'WV', 'AK', 'NM', 'MN', 'VT', 'MI', 'LA'], dtype=object)

# %% [markdown]
# convert phone column data type to string

# %%
df_us_customer['phone']=df_us_customer['phone'].fillna(0)
df_us_customer['phone']=df_us_customer['phone'].astype(str)

# %% [markdown]
# check the standard length of the phone number and standardize according to the country and their phone number code

# %%
def standard_phone(df_us_customer):
    si=len(df_us_customer['phone'])
    for i in range(si):
        if len(df_us_customer['phone'][i])>12 or len(df_us_customer['phone'][i])<12:
            df_us_customer['phone'][i]='0'
        elif df_us_customer['country_code'][i]=='IN':
            df_us_customer['phone'][i]='+91 '+str (df_us_customer['phone'][i])
        elif df_us_customer['country_code'][i]=='PW':
            df_us_customer['phone'][i]='+680 '+str (df_us_customer['phone'][i])
        elif df_us_customer['country_code'][i]=='FM':
            df_us_customer['phone'][i]='+691 '+str (df_us_customer['phone'][i])
        elif df_us_customer['country_code'][i]=='AE':
            df_us_customer['phone'][i]='+971 '+str (df_us_customer['phone'][i])
        else:
            df_us_customer['phone'][i]='+1 '+str (df_us_customer['phone'][i])
        
        
    return df_us_customer

standard_phone(df_us_customer)
# Out:
# C:\Users\Dheepansh\AppData\Local\Temp\ipykernel_4468\1655941170.py:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_us_customer['phone'][i]='+971 '+str (df_us_customer['phone'][i])
# ...

# %% [markdown]
# merge the files

# %%
df_merged=pd.merge(df_us_customer,df_transaction,on='customer_id')

# %% [markdown]
# convert to csv file

# %%
df_merged.to_csv('df_merged.csv',index=False)
